# %% [markdown]
# # 필요 패키지 설치

# %%
# 라이브러리 설치
# !pip install transformers -q
# !pip install datasets -q
# !pip install sentencepiece -q

# 모델 평가용
# !pip install evaluate
# !pip install sacrebleu

# %% [markdown]
# # Data Set
# ### 허깅페이스 사이트에 접속
# ### 상단 메뉴에 Datasets - 좌측 작은 메뉴에서 Languages - korean - 검색 필터 창에 en
